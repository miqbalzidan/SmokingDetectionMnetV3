# %% [markdown]
# # Import package and module

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
from itertools import zip_longest

# %%
tf.config.list_physical_devices("GPU")
# !nvidia-smi
# Out:
# Wed May 18 09:39:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.89       Driver Version: 460.89       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 166... WDDM  | 00000000:29:00.0  On |                  N/A |
# |  0%   50C    P8    20W / 125W |    837MiB /  6144MiB |     15%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1256    C+G   C:\Windows\System32\dwm.exe     N/A      |
# |    0   N/A  N/A      1396    C+G   ...er_engine\wallpaper64.exe    N/A      |
# |    0   N/A  N/A      1872    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      3364    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      3600    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      5180    C+G   ...wekyb3d8bbwe\Music.UI.exe    N/A      |
# |    0   N/A  N/A      6900    C+G   ..._dt26b99r8h8gj\RtkUWP.exe    N/A      |
# |    0   N/A  N/A      7560    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A      8188    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      9464    C+G   ...erver\YourPhoneServer.exe    N/A      |
# |    0   N/A  N/A      9584    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9740    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A     10220    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     10848    C+G   ...ll\1.0.0.443\LineCall.exe    N/A      |
# |    0   N/A  N/A     10964    C+G   ...\app-1.0.9004\Discord.exe    N/A      |
# |    0   N/A  N/A     11076    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     13636    C+G   ...LINE\bin\current\LINE.exe    N/A      |
# |    0   N/A  N/A     17480    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     17484    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     19380    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# |    0   N/A  N/A     19424    C+G   ...ekyb3d8bbwe\HxOutlook.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Load path

# %%
try:
    set_pick = int(input("Dataset : \n1. Kaggle\n2. Mendley"))
    if set_pick == 1:
        # Dataset dir
        train_dir = './cigarette-smoker-detection-kaggle/train'
        test_dir = './cigarette-smoker-detection-kaggle/test'

        print("Kaggle dataset selected")

    elif set_pick == 2:
        # Dataset dir 
        train_dir = './dataset_mendley/training_data'
        val_dir = './dataset_mendley/validation_data'
        test_dir = './dataset_mendley/testing_data'
        
        print("Mendley dataset selected")
    else:
        raise Exception("Input 1 or 2")
except ValueError:
    print("Wrong input value!!!")
# Out:
# Mendley dataset selected

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Preprocessing

# %%
img_size = 224
batch_size = 32
seed = 72

if set_pick == 1:

    train_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        validation_split=0.2,
        subset="training",
        seed=seed,
        label_mode="binary",
        image_size=(img_size, img_size),
        batch_size=batch_size
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        validation_split=0.2,
        subset="validation",
        seed=seed,
        label_mode="binary",
        image_size=(img_size,img_size),
        batch_size=batch_size
    )

elif set_pick == 2:

    train_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        seed=seed,
        label_mode="binary",
        image_size=(img_size, img_size),
        batch_size=batch_size
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        seed=seed,
        label_mode="binary",
        image_size=(img_size,img_size),
        batch_size=batch_size
    )

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    seed=seed,
    label_mode="binary",
    image_size=(img_size, img_size),
    batch_size=batch_size
)
# Out:
# Found 1610 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.

# %%
train_ds.class_names
# Out:
# ['notsmoking', 'smoking']

# %% [markdown]
# ## Rescale

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))
print("\nRescale Successful")
# Out:
# Rescale Successful

# %% [markdown]
# # Train

# %%
base_model = tf.keras.applications.MobileNetV3Large(
    input_shape=(img_size, img_size, 3),
    weights="imagenet",
    include_preprocessing=False,
    include_top=False,
    pooling="avg"
)

# base_model.trainable = False
for layer in base_model.layers[:-7]:
    layer.trainable = False

# %%
model = tf.keras.Sequential([
                            base_model,
                            #tf.keras.layers.Dropout(0.2, seed = seed),
                            tf.keras.layers.Dense(units=1, activation = "sigmoid")
])

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy", 
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall()
                       #,tfa.metrics.F1Score(num_classes= 2 )
                       ])

# %% [markdown]
# Model Summary

# %%
model.summary(expand_nested=True)
# tf.keras.utils.plot_model(
#     model,
#     show_shapes=True
# )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Functiona  (None, 960)              2996352
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)      [(None, 224, 224, 3)]     0         |
# |                                                               |
# | Conv (Conv2D)             (None, 112, 112, 16)      432       |
# |                                                               |
# | Conv/BatchNorm (BatchNormal  (None, 112, 112, 16)   64        |
# | ization)                                                      |
# |                                                               |
# | tf.__operators__.add (TFOpL  (None, 112, 112, 16)   0         |
# | ambda)                                                        |
# |                                                               |
# | re_lu (ReLU)              (None, 112, 112, 16)      0         |
# |                                                               |
# | tf.math.multiply (TFOpLambd  (None, 112, 112, 16)   0         |
# | a)                                                            |
# |                                                               |
# | multiply (Multiply)       (None, 112, 112, 16)      0         |
# |                                                               |
# | expanded_conv/depthwise (De  (None, 112, 112, 16)   144       |
# | pthwiseConv2D)                                                |
# |                                                               |
# | expanded_conv/depthwise/Bat  (None, 112, 112, 16)   64        |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | re_lu_1 (ReLU)            (None, 112, 112, 16)      0         |
# |                                                               |
# | expanded_conv/project (Conv  (None, 112, 112, 16)   256       |
# | 2D)                                                           |
# |                                                               |
# | expanded_conv/project/Batch  (None, 112, 112, 16)   64        |
# | Norm (BatchNormalization)                                     |
# |                                                               |
# | expanded_conv/Add (Add)   (None, 112, 112, 16)      0         |
# |                                                               |
# | expanded_conv_1/expand (Con  (None, 112, 112, 64)   1024      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_1/expand/Batc  (None, 112, 112, 64)   256       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | re_lu_2 (ReLU)            (None, 112, 112, 64)      0         |
# |                                                               |
# | expanded_conv_1/depthwise/p  (None, 113, 113, 64)   0         |
# | ad (ZeroPadding2D)                                            |
# |                                                               |
# | expanded_conv_1/depthwise (  (None, 56, 56, 64)     576       |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_1/depthwise/B  (None, 56, 56, 64)     256       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | re_lu_3 (ReLU)            (None, 56, 56, 64)        0         |
# |                                                               |
# | expanded_conv_1/project (Co  (None, 56, 56, 24)     1536      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_1/project/Bat  (None, 56, 56, 24)     96        |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_2/expand (Con  (None, 56, 56, 72)     1728      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_2/expand/Batc  (None, 56, 56, 72)     288       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | re_lu_4 (ReLU)            (None, 56, 56, 72)        0         |
# |                                                               |
# | expanded_conv_2/depthwise (  (None, 56, 56, 72)     648       |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_2/depthwise/B  (None, 56, 56, 72)     288       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | re_lu_5 (ReLU)            (None, 56, 56, 72)        0         |
# |                                                               |
# | expanded_conv_2/project (Co  (None, 56, 56, 24)     1728      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_2/project/Bat  (None, 56, 56, 24)     96        |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_2/Add (Add)  (None, 56, 56, 24)       0         |
# |                                                               |
# | expanded_conv_3/expand (Con  (None, 56, 56, 72)     1728      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_3/expand/Batc  (None, 56, 56, 72)     288       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | re_lu_6 (ReLU)            (None, 56, 56, 72)        0         |
# |                                                               |
# | expanded_conv_3/depthwise/p  (None, 59, 59, 72)     0         |
# | ad (ZeroPadding2D)                                            |
# |                                                               |
# | expanded_conv_3/depthwise (  (None, 28, 28, 72)     1800      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_3/depthwise/B  (None, 28, 28, 72)     288       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | re_lu_7 (ReLU)            (None, 28, 28, 72)        0         |
# |                                                               |
# | expanded_conv_3/squeeze_exc  (None, 1, 1, 72)       0         |
# | ite/AvgPool (GlobalAverageP                                   |
# | ooling2D)                                                     |
# |                                                               |
# | expanded_conv_3/squeeze_exc  (None, 1, 1, 24)       1752      |
# | ite/Conv (Conv2D)                                             |
# |                                                               |
# | expanded_conv_3/squeeze_exc  (None, 1, 1, 24)       0         |
# | ite/Relu (ReLU)                                               |
# |                                                               |
# | expanded_conv_3/squeeze_exc  (None, 1, 1, 72)       1800      |
# | ite/Conv_1 (Conv2D)                                           |
# |                                                               |
# | tf.__operators__.add_1 (TFO  (None, 1, 1, 72)       0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_8 (ReLU)            (None, 1, 1, 72)          0         |
# |                                                               |
# | tf.math.multiply_1 (TFOpLam  (None, 1, 1, 72)       0         |
# | bda)                                                          |
# |                                                               |
# | expanded_conv_3/squeeze_exc  (None, 28, 28, 72)     0         |
# | ite/Mul (Multiply)                                            |
# |                                                               |
# | expanded_conv_3/project (Co  (None, 28, 28, 40)     2880      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_3/project/Bat  (None, 28, 28, 40)     160       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_4/expand (Con  (None, 28, 28, 120)    4800      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_4/expand/Batc  (None, 28, 28, 120)    480       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | re_lu_9 (ReLU)            (None, 28, 28, 120)       0         |
# |                                                               |
# | expanded_conv_4/depthwise (  (None, 28, 28, 120)    3000      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_4/depthwise/B  (None, 28, 28, 120)    480       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | re_lu_10 (ReLU)           (None, 28, 28, 120)       0         |
# |                                                               |
# | expanded_conv_4/squeeze_exc  (None, 1, 1, 120)      0         |
# | ite/AvgPool (GlobalAverageP                                   |
# | ooling2D)                                                     |
# |                                                               |
# | expanded_conv_4/squeeze_exc  (None, 1, 1, 32)       3872      |
# | ite/Conv (Conv2D)                                             |
# |                                                               |
# | expanded_conv_4/squeeze_exc  (None, 1, 1, 32)       0         |
# | ite/Relu (ReLU)                                               |
# |                                                               |
# | expanded_conv_4/squeeze_exc  (None, 1, 1, 120)      3960      |
# | ite/Conv_1 (Conv2D)                                           |
# |                                                               |
# | tf.__operators__.add_2 (TFO  (None, 1, 1, 120)      0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_11 (ReLU)           (None, 1, 1, 120)         0         |
# |                                                               |
# | tf.math.multiply_2 (TFOpLam  (None, 1, 1, 120)      0         |
# | bda)                                                          |
# |                                                               |
# | expanded_conv_4/squeeze_exc  (None, 28, 28, 120)    0         |
# | ite/Mul (Multiply)                                            |
# |                                                               |
# | expanded_conv_4/project (Co  (None, 28, 28, 40)     4800      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_4/project/Bat  (None, 28, 28, 40)     160       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_4/Add (Add)  (None, 28, 28, 40)       0         |
# |                                                               |
# | expanded_conv_5/expand (Con  (None, 28, 28, 120)    4800      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_5/expand/Batc  (None, 28, 28, 120)    480       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | re_lu_12 (ReLU)           (None, 28, 28, 120)       0         |
# |                                                               |
# | expanded_conv_5/depthwise (  (None, 28, 28, 120)    3000      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_5/depthwise/B  (None, 28, 28, 120)    480       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | re_lu_13 (ReLU)           (None, 28, 28, 120)       0         |
# |                                                               |
# | expanded_conv_5/squeeze_exc  (None, 1, 1, 120)      0         |
# | ite/AvgPool (GlobalAverageP                                   |
# | ooling2D)                                                     |
# |                                                               |
# | expanded_conv_5/squeeze_exc  (None, 1, 1, 32)       3872      |
# | ite/Conv (Conv2D)                                             |
# |                                                               |
# | expanded_conv_5/squeeze_exc  (None, 1, 1, 32)       0         |
# | ite/Relu (ReLU)                                               |
# |                                                               |
# | expanded_conv_5/squeeze_exc  (None, 1, 1, 120)      3960      |
# | ite/Conv_1 (Conv2D)                                           |
# |                                                               |
# | tf.__operators__.add_3 (TFO  (None, 1, 1, 120)      0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_14 (ReLU)           (None, 1, 1, 120)         0         |
# |                                                               |
# | tf.math.multiply_3 (TFOpLam  (None, 1, 1, 120)      0         |
# | bda)                                                          |
# |                                                               |
# | expanded_conv_5/squeeze_exc  (None, 28, 28, 120)    0         |
# | ite/Mul (Multiply)                                            |
# |                                                               |
# | expanded_conv_5/project (Co  (None, 28, 28, 40)     4800      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_5/project/Bat  (None, 28, 28, 40)     160       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_5/Add (Add)  (None, 28, 28, 40)       0         |
# |                                                               |
# | expanded_conv_6/expand (Con  (None, 28, 28, 240)    9600      |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_6/expand/Batc  (None, 28, 28, 240)    960       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | tf.__operators__.add_4 (TFO  (None, 28, 28, 240)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_15 (ReLU)           (None, 28, 28, 240)       0         |
# |                                                               |
# | tf.math.multiply_4 (TFOpLam  (None, 28, 28, 240)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_1 (Multiply)     (None, 28, 28, 240)       0         |
# |                                                               |
# | expanded_conv_6/depthwise/p  (None, 29, 29, 240)    0         |
# | ad (ZeroPadding2D)                                            |
# |                                                               |
# | expanded_conv_6/depthwise (  (None, 14, 14, 240)    2160      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_6/depthwise/B  (None, 14, 14, 240)    960       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | tf.__operators__.add_5 (TFO  (None, 14, 14, 240)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_16 (ReLU)           (None, 14, 14, 240)       0         |
# |                                                               |
# | tf.math.multiply_5 (TFOpLam  (None, 14, 14, 240)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_2 (Multiply)     (None, 14, 14, 240)       0         |
# |                                                               |
# | expanded_conv_6/project (Co  (None, 14, 14, 80)     19200     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_6/project/Bat  (None, 14, 14, 80)     320       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_7/expand (Con  (None, 14, 14, 200)    16000     |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_7/expand/Batc  (None, 14, 14, 200)    800       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | tf.__operators__.add_6 (TFO  (None, 14, 14, 200)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_17 (ReLU)           (None, 14, 14, 200)       0         |
# |                                                               |
# | tf.math.multiply_6 (TFOpLam  (None, 14, 14, 200)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_3 (Multiply)     (None, 14, 14, 200)       0         |
# |                                                               |
# | expanded_conv_7/depthwise (  (None, 14, 14, 200)    1800      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_7/depthwise/B  (None, 14, 14, 200)    800       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | tf.__operators__.add_7 (TFO  (None, 14, 14, 200)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_18 (ReLU)           (None, 14, 14, 200)       0         |
# |                                                               |
# | tf.math.multiply_7 (TFOpLam  (None, 14, 14, 200)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_4 (Multiply)     (None, 14, 14, 200)       0         |
# |                                                               |
# | expanded_conv_7/project (Co  (None, 14, 14, 80)     16000     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_7/project/Bat  (None, 14, 14, 80)     320       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_7/Add (Add)  (None, 14, 14, 80)       0         |
# |                                                               |
# | expanded_conv_8/expand (Con  (None, 14, 14, 184)    14720     |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_8/expand/Batc  (None, 14, 14, 184)    736       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | tf.__operators__.add_8 (TFO  (None, 14, 14, 184)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_19 (ReLU)           (None, 14, 14, 184)       0         |
# |                                                               |
# | tf.math.multiply_8 (TFOpLam  (None, 14, 14, 184)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_5 (Multiply)     (None, 14, 14, 184)       0         |
# |                                                               |
# | expanded_conv_8/depthwise (  (None, 14, 14, 184)    1656      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_8/depthwise/B  (None, 14, 14, 184)    736       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | tf.__operators__.add_9 (TFO  (None, 14, 14, 184)    0         |
# | pLambda)                                                      |
# |                                                               |
# | re_lu_20 (ReLU)           (None, 14, 14, 184)       0         |
# |                                                               |
# | tf.math.multiply_9 (TFOpLam  (None, 14, 14, 184)    0         |
# | bda)                                                          |
# |                                                               |
# | multiply_6 (Multiply)     (None, 14, 14, 184)       0         |
# |                                                               |
# | expanded_conv_8/project (Co  (None, 14, 14, 80)     14720     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_8/project/Bat  (None, 14, 14, 80)     320       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_8/Add (Add)  (None, 14, 14, 80)       0         |
# |                                                               |
# | expanded_conv_9/expand (Con  (None, 14, 14, 184)    14720     |
# | v2D)                                                          |
# |                                                               |
# | expanded_conv_9/expand/Batc  (None, 14, 14, 184)    736       |
# | hNorm (BatchNormalization)                                    |
# |                                                               |
# | tf.__operators__.add_10 (TF  (None, 14, 14, 184)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_21 (ReLU)           (None, 14, 14, 184)       0         |
# |                                                               |
# | tf.math.multiply_10 (TFOpLa  (None, 14, 14, 184)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_7 (Multiply)     (None, 14, 14, 184)       0         |
# |                                                               |
# | expanded_conv_9/depthwise (  (None, 14, 14, 184)    1656      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv_9/depthwise/B  (None, 14, 14, 184)    736       |
# | atchNorm (BatchNormalizatio                                   |
# | n)                                                            |
# |                                                               |
# | tf.__operators__.add_11 (TF  (None, 14, 14, 184)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_22 (ReLU)           (None, 14, 14, 184)       0         |
# |                                                               |
# | tf.math.multiply_11 (TFOpLa  (None, 14, 14, 184)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_8 (Multiply)     (None, 14, 14, 184)       0         |
# |                                                               |
# | expanded_conv_9/project (Co  (None, 14, 14, 80)     14720     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_9/project/Bat  (None, 14, 14, 80)     320       |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | expanded_conv_9/Add (Add)  (None, 14, 14, 80)       0         |
# |                                                               |
# | expanded_conv_10/expand (Co  (None, 14, 14, 480)    38400     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_10/expand/Bat  (None, 14, 14, 480)    1920      |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | tf.__operators__.add_12 (TF  (None, 14, 14, 480)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_23 (ReLU)           (None, 14, 14, 480)       0         |
# |                                                               |
# | tf.math.multiply_12 (TFOpLa  (None, 14, 14, 480)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_9 (Multiply)     (None, 14, 14, 480)       0         |
# |                                                               |
# | expanded_conv_10/depthwise   (None, 14, 14, 480)    4320      |
# | (DepthwiseConv2D)                                             |
# |                                                               |
# | expanded_conv_10/depthwise/  (None, 14, 14, 480)    1920      |
# | BatchNorm (BatchNormalizati                                   |
# | on)                                                           |
# |                                                               |
# | tf.__operators__.add_13 (TF  (None, 14, 14, 480)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_24 (ReLU)           (None, 14, 14, 480)       0         |
# |                                                               |
# | tf.math.multiply_13 (TFOpLa  (None, 14, 14, 480)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_10 (Multiply)    (None, 14, 14, 480)       0         |
# |                                                               |
# | expanded_conv_10/squeeze_ex  (None, 1, 1, 480)      0         |
# | cite/AvgPool (GlobalAverage                                   |
# | Pooling2D)                                                    |
# |                                                               |
# | expanded_conv_10/squeeze_ex  (None, 1, 1, 120)      57720     |
# | cite/Conv (Conv2D)                                            |
# |                                                               |
# | expanded_conv_10/squeeze_ex  (None, 1, 1, 120)      0         |
# | cite/Relu (ReLU)                                              |
# |                                                               |
# | expanded_conv_10/squeeze_ex  (None, 1, 1, 480)      58080     |
# | cite/Conv_1 (Conv2D)                                          |
# |                                                               |
# | tf.__operators__.add_14 (TF  (None, 1, 1, 480)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_25 (ReLU)           (None, 1, 1, 480)         0         |
# |                                                               |
# | tf.math.multiply_14 (TFOpLa  (None, 1, 1, 480)      0         |
# | mbda)                                                         |
# |                                                               |
# | expanded_conv_10/squeeze_ex  (None, 14, 14, 480)    0         |
# | cite/Mul (Multiply)                                           |
# |                                                               |
# | expanded_conv_10/project (C  (None, 14, 14, 112)    53760     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_10/project/Ba  (None, 14, 14, 112)    448       |
# | tchNorm (BatchNormalization                                   |
# | )                                                             |
# |                                                               |
# | expanded_conv_11/expand (Co  (None, 14, 14, 672)    75264     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_11/expand/Bat  (None, 14, 14, 672)    2688      |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | tf.__operators__.add_15 (TF  (None, 14, 14, 672)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_26 (ReLU)           (None, 14, 14, 672)       0         |
# |                                                               |
# | tf.math.multiply_15 (TFOpLa  (None, 14, 14, 672)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_11 (Multiply)    (None, 14, 14, 672)       0         |
# |                                                               |
# | expanded_conv_11/depthwise   (None, 14, 14, 672)    6048      |
# | (DepthwiseConv2D)                                             |
# |                                                               |
# | expanded_conv_11/depthwise/  (None, 14, 14, 672)    2688      |
# | BatchNorm (BatchNormalizati                                   |
# | on)                                                           |
# |                                                               |
# | tf.__operators__.add_16 (TF  (None, 14, 14, 672)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_27 (ReLU)           (None, 14, 14, 672)       0         |
# |                                                               |
# | tf.math.multiply_16 (TFOpLa  (None, 14, 14, 672)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_12 (Multiply)    (None, 14, 14, 672)       0         |
# |                                                               |
# | expanded_conv_11/squeeze_ex  (None, 1, 1, 672)      0         |
# | cite/AvgPool (GlobalAverage                                   |
# | Pooling2D)                                                    |
# |                                                               |
# | expanded_conv_11/squeeze_ex  (None, 1, 1, 168)      113064    |
# | cite/Conv (Conv2D)                                            |
# |                                                               |
# | expanded_conv_11/squeeze_ex  (None, 1, 1, 168)      0         |
# | cite/Relu (ReLU)                                              |
# |                                                               |
# | expanded_conv_11/squeeze_ex  (None, 1, 1, 672)      113568    |
# | cite/Conv_1 (Conv2D)                                          |
# |                                                               |
# | tf.__operators__.add_17 (TF  (None, 1, 1, 672)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_28 (ReLU)           (None, 1, 1, 672)         0         |
# |                                                               |
# | tf.math.multiply_17 (TFOpLa  (None, 1, 1, 672)      0         |
# | mbda)                                                         |
# |                                                               |
# | expanded_conv_11/squeeze_ex  (None, 14, 14, 672)    0         |
# | cite/Mul (Multiply)                                           |
# |                                                               |
# | expanded_conv_11/project (C  (None, 14, 14, 112)    75264     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_11/project/Ba  (None, 14, 14, 112)    448       |
# | tchNorm (BatchNormalization                                   |
# | )                                                             |
# |                                                               |
# | expanded_conv_11/Add (Add)  (None, 14, 14, 112)     0         |
# |                                                               |
# | expanded_conv_12/expand (Co  (None, 14, 14, 672)    75264     |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_12/expand/Bat  (None, 14, 14, 672)    2688      |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | tf.__operators__.add_18 (TF  (None, 14, 14, 672)    0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_29 (ReLU)           (None, 14, 14, 672)       0         |
# |                                                               |
# | tf.math.multiply_18 (TFOpLa  (None, 14, 14, 672)    0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_13 (Multiply)    (None, 14, 14, 672)       0         |
# |                                                               |
# | expanded_conv_12/depthwise/  (None, 17, 17, 672)    0         |
# | pad (ZeroPadding2D)                                           |
# |                                                               |
# | expanded_conv_12/depthwise   (None, 7, 7, 672)      16800     |
# | (DepthwiseConv2D)                                             |
# |                                                               |
# | expanded_conv_12/depthwise/  (None, 7, 7, 672)      2688      |
# | BatchNorm (BatchNormalizati                                   |
# | on)                                                           |
# |                                                               |
# | tf.__operators__.add_19 (TF  (None, 7, 7, 672)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_30 (ReLU)           (None, 7, 7, 672)         0         |
# |                                                               |
# | tf.math.multiply_19 (TFOpLa  (None, 7, 7, 672)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_14 (Multiply)    (None, 7, 7, 672)         0         |
# |                                                               |
# | expanded_conv_12/squeeze_ex  (None, 1, 1, 672)      0         |
# | cite/AvgPool (GlobalAverage                                   |
# | Pooling2D)                                                    |
# |                                                               |
# | expanded_conv_12/squeeze_ex  (None, 1, 1, 168)      113064    |
# | cite/Conv (Conv2D)                                            |
# |                                                               |
# | expanded_conv_12/squeeze_ex  (None, 1, 1, 168)      0         |
# | cite/Relu (ReLU)                                              |
# |                                                               |
# | expanded_conv_12/squeeze_ex  (None, 1, 1, 672)      113568    |
# | cite/Conv_1 (Conv2D)                                          |
# |                                                               |
# | tf.__operators__.add_20 (TF  (None, 1, 1, 672)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_31 (ReLU)           (None, 1, 1, 672)         0         |
# |                                                               |
# | tf.math.multiply_20 (TFOpLa  (None, 1, 1, 672)      0         |
# | mbda)                                                         |
# |                                                               |
# | expanded_conv_12/squeeze_ex  (None, 7, 7, 672)      0         |
# | cite/Mul (Multiply)                                           |
# |                                                               |
# | expanded_conv_12/project (C  (None, 7, 7, 160)      107520    |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_12/project/Ba  (None, 7, 7, 160)      640       |
# | tchNorm (BatchNormalization                                   |
# | )                                                             |
# |                                                               |
# | expanded_conv_13/expand (Co  (None, 7, 7, 960)      153600    |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_13/expand/Bat  (None, 7, 7, 960)      3840      |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | tf.__operators__.add_21 (TF  (None, 7, 7, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_32 (ReLU)           (None, 7, 7, 960)         0         |
# |                                                               |
# | tf.math.multiply_21 (TFOpLa  (None, 7, 7, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_15 (Multiply)    (None, 7, 7, 960)         0         |
# |                                                               |
# | expanded_conv_13/depthwise   (None, 7, 7, 960)      24000     |
# | (DepthwiseConv2D)                                             |
# |                                                               |
# | expanded_conv_13/depthwise/  (None, 7, 7, 960)      3840      |
# | BatchNorm (BatchNormalizati                                   |
# | on)                                                           |
# |                                                               |
# | tf.__operators__.add_22 (TF  (None, 7, 7, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_33 (ReLU)           (None, 7, 7, 960)         0         |
# |                                                               |
# | tf.math.multiply_22 (TFOpLa  (None, 7, 7, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_16 (Multiply)    (None, 7, 7, 960)         0         |
# |                                                               |
# | expanded_conv_13/squeeze_ex  (None, 1, 1, 960)      0         |
# | cite/AvgPool (GlobalAverage                                   |
# | Pooling2D)                                                    |
# |                                                               |
# | expanded_conv_13/squeeze_ex  (None, 1, 1, 240)      230640    |
# | cite/Conv (Conv2D)                                            |
# |                                                               |
# | expanded_conv_13/squeeze_ex  (None, 1, 1, 240)      0         |
# | cite/Relu (ReLU)                                              |
# |                                                               |
# | expanded_conv_13/squeeze_ex  (None, 1, 1, 960)      231360    |
# | cite/Conv_1 (Conv2D)                                          |
# |                                                               |
# | tf.__operators__.add_23 (TF  (None, 1, 1, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_34 (ReLU)           (None, 1, 1, 960)         0         |
# |                                                               |
# | tf.math.multiply_23 (TFOpLa  (None, 1, 1, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | expanded_conv_13/squeeze_ex  (None, 7, 7, 960)      0         |
# | cite/Mul (Multiply)                                           |
# |                                                               |
# | expanded_conv_13/project (C  (None, 7, 7, 160)      153600    |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_13/project/Ba  (None, 7, 7, 160)      640       |
# | tchNorm (BatchNormalization                                   |
# | )                                                             |
# |                                                               |
# | expanded_conv_13/Add (Add)  (None, 7, 7, 160)       0         |
# |                                                               |
# | expanded_conv_14/expand (Co  (None, 7, 7, 960)      153600    |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv_14/expand/Bat  (None, 7, 7, 960)      3840      |
# | chNorm (BatchNormalization)                                   |
# |                                                               |
# | tf.__operators__.add_24 (TF  (None, 7, 7, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_35 (ReLU)           (None, 7, 7, 960)         0         |
# |                                                               |
# | tf.math.multiply_24 (TFOpLa  (None, 7, 7, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_17 (Multiply)    (None, 7, 7, 960)         0         |
# |                                                               |
# | expanded_conv_14/depthwise   (None, 7, 7, 960)      24000     |
# | (DepthwiseConv2D)                                             |
# |                                                               |
# | expanded_conv_14/depthwise/  (None, 7, 7, 960)      3840      |
# | BatchNorm (BatchNormalizati                                   |
# | on)                                                           |
# |                                                               |
# | tf.__operators__.add_25 (TF  (None, 7, 7, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_36 (ReLU)           (None, 7, 7, 960)         0         |
# |                                                               |
# | tf.math.multiply_25 (TFOpLa  (None, 7, 7, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_18 (Multiply)    (None, 7, 7, 960)         0         |
# |                                                               |
# | expanded_conv_14/squeeze_ex  (None, 1, 1, 960)      0         |
# | cite/AvgPool (GlobalAverage                                   |
# | Pooling2D)                                                    |
# |                                                               |
# | expanded_conv_14/squeeze_ex  (None, 1, 1, 240)      230640    |
# | cite/Conv (Conv2D)                                            |
# |                                                               |
# | expanded_conv_14/squeeze_ex  (None, 1, 1, 240)      0         |
# | cite/Relu (ReLU)                                              |
# |                                                               |
# | expanded_conv_14/squeeze_ex  (None, 1, 1, 960)      231360    |
# | cite/Conv_1 (Conv2D)                                          |
# |                                                               |
# | tf.__operators__.add_26 (TF  (None, 1, 1, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_37 (ReLU)           (None, 1, 1, 960)         0         |
# |                                                               |
# | tf.math.multiply_26 (TFOpLa  (None, 1, 1, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | expanded_conv_14/squeeze_ex  (None, 7, 7, 960)      0         |
# | cite/Mul (Multiply)                                           |
# |                                                               |
# | expanded_conv_14/project (C  (None, 7, 7, 160)      153600    |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_14/project/Ba  (None, 7, 7, 160)      640       |
# | tchNorm (BatchNormalization                                   |
# | )                                                             |
# |                                                               |
# | expanded_conv_14/Add (Add)  (None, 7, 7, 160)       0         |
# |                                                               |
# | Conv_1 (Conv2D)           (None, 7, 7, 960)         153600    |
# |                                                               |
# | Conv_1/BatchNorm (BatchNorm  (None, 7, 7, 960)      3840      |
# | alization)                                                    |
# |                                                               |
# | tf.__operators__.add_27 (TF  (None, 7, 7, 960)      0         |
# | OpLambda)                                                     |
# |                                                               |
# | re_lu_38 (ReLU)           (None, 7, 7, 960)         0         |
# |                                                               |
# | tf.math.multiply_27 (TFOpLa  (None, 7, 7, 960)      0         |
# | mbda)                                                         |
# |                                                               |
# | multiply_19 (Multiply)    (None, 7, 7, 960)         0         |
# |                                                               |
# | avg_pool (GlobalAveragePool  (None, 960)            0         |
# | ing2D)                                                        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  dense (Dense)               (None, 1)                 961
#
# =================================================================
# Total params: 2,997,313
# Trainable params: 156,481
# Non-trainable params: 2,840,832
# _________________________________________________________________

# %%
fb_model = tf.lite.TFLiteConverter.from_keras_model(model).convert()

tf.lite.experimental.Analyzer.analyze(model_content=fb_model)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) MobilenetV3large_input with unsupported characters which will be renamed to mobilenetv3large_input in the SavedModel.
# INFO:tensorflow:Assets written to: C:\Users\Aisen\AppData\Local\Temp\tmpva5uu1zw\assets
# INFO:tensorflow:Assets written to: C:\Users\Aisen\AppData\Local\Temp\tmpva5uu1zw\assets
# === TFLite ModelAnalyzer ===
#
# Your TFLite model has '1' subgraph(s). In the subgraph description below,
# T# represents the Tensor numbers. For example, in Subgraph#0, the CONV_2D op takes
# tensor #0 and tensor #43 and tensor #90 as input and produces tensor #131 as output.
#
# Subgraph#0 main(T#0) -> [T#253]
#   Op#0 CONV_2D(T#0, T#43, T#90) -> [T#131]
#   Op#1 HARD_SWISH(T#131) -> [T#132]
#   Op#2 DEPTHWISE_CONV_2D(T#132, T#91, T#22) -> [T#133]
#   Op#3 CONV_2D(T#133, T#44, T#92) -> [T#134]
#   Op#4 ADD(T#132, T#134) -> [T#135]
#   Op#5 CONV_2D(T#135, T#45, T#23) -> [T#136]
#   Op#6 PAD(T#136, T#19) -> [T#137]
#   Op#7 DEPTHWISE_CONV_2D(T#137, T#93, T#24) -> [T#138]
#   Op#8 CONV_2D(T#138, T#46, T#94) -> [T#139]
#   Op#9 CONV_2D(T#139, T#47, T#25) -> [T#140]
#   Op#10 DEPTHWISE_CONV_2D(T#140, T#95, T#26) -> [T#141]
#   Op#11 CONV_2D(T#141, T#48, T#96) -> [T#142]
#   Op#12 ADD(T#139, T#142) -> [T#143]
#   Op#13 CONV_2D(T#143, T#49, T#27) -> [T#144]
#   Op#14 PAD(T#144, T#21) -> [T#145]
#   Op#15 DEPTHWISE_CONV_2D(T#145, T#97, T#28) -> [T#146]
#   Op#16 MEAN(T#146, T#20) -> [T#147]
#   Op#17 CONV_2D(T#147, T#50, T#3) -> [T#148]
#   Op#18 CONV_2D(T#148, T#51, T#11) -> [T#149]
#   Op#19 MUL(T#149, T#10) -> [T#150]
#   Op#20 MUL(T#146, T#150) -> [T#151]
#   Op#21 CONV_2D(T#151, T#52, T#98) -> [T#152]
#   Op#22 CONV_2D(T#152, T#53, T#29) -> [T#153]
#   Op#23 DEPTHWISE_CONV_2D(T#153, T#99, T#30) -> [T#154]
#   Op#24 MEAN(T#154, T#20) -> [T#155]
#   Op#25 CONV_2D(T#155, T#54, T#2) -> [T#156]
#   Op#26 CONV_2D(T#156, T#55, T#12) -> [T#157]
#   Op#27 MUL(T#157, T#10) -> [T#158]
#   Op#28 MUL(T#154, T#158) -> [T#159]
#   Op#29 CONV_2D(T#159, T#56, T#100) -> [T#160]
#   Op#30 ADD(T#152, T#160) -> [T#161]
#   Op#31 CONV_2D(T#161, T#57, T#31) -> [T#162]
#   Op#32 DEPTHWISE_CONV_2D(T#162, T#101, T#32) -> [T#163]
#   Op#33 MEAN(T#163, T#20) -> [T#164]
#   Op#34 CONV_2D(T#164, T#58, T#1) -> [T#165]
#   Op#35 CONV_2D(T#165, T#59, T#13) -> [T#166]
#   Op#36 MUL(T#166, T#10) -> [T#167]
#   Op#37 MUL(T#163, T#167) -> [T#168]
#   Op#38 CONV_2D(T#168, T#60, T#102) -> [T#169]
#   Op#39 ADD(T#161, T#169) -> [T#170]
#   Op#40 CONV_2D(T#170, T#61, T#103) -> [T#171]
#   Op#41 HARD_SWISH(T#171) -> [T#172]
#   Op#42 PAD(T#172, T#19) -> [T#173]
#   Op#43 DEPTHWISE_CONV_2D(T#173, T#104, T#33) -> [T#174]
#   Op#44 HARD_SWISH(T#174) -> [T#175]
#   Op#45 CONV_2D(T#175, T#62, T#105) -> [T#176]
#   Op#46 CONV_2D(T#176, T#63, T#106) -> [T#177]
#   Op#47 HARD_SWISH(T#177) -> [T#178]
#   Op#48 DEPTHWISE_CONV_2D(T#178, T#107, T#34) -> [T#179]
#   Op#49 HARD_SWISH(T#179) -> [T#180]
#   Op#50 CONV_2D(T#180, T#64, T#108) -> [T#181]
#   Op#51 ADD(T#176, T#181) -> [T#182]
#   Op#52 CONV_2D(T#182, T#65, T#109) -> [T#183]
#   Op#53 HARD_SWISH(T#183) -> [T#184]
#   Op#54 DEPTHWISE_CONV_2D(T#184, T#110, T#35) -> [T#185]
#   Op#55 HARD_SWISH(T#185) -> [T#186]
#   Op#56 CONV_2D(T#186, T#66, T#111) -> [T#187]
#   Op#57 ADD(T#182, T#187) -> [T#188]
#   Op#58 CONV_2D(T#188, T#67, T#112) -> [T#189]
#   Op#59 HARD_SWISH(T#189) -> [T#190]
#   Op#60 DEPTHWISE_CONV_2D(T#190, T#113, T#36) -> [T#191]
#   Op#61 HARD_SWISH(T#191) -> [T#192]
#   Op#62 CONV_2D(T#192, T#68, T#114) -> [T#193]
#   Op#63 ADD(T#188, T#193) -> [T#194]
#   Op#64 CONV_2D(T#194, T#69, T#115) -> [T#195]
#   Op#65 HARD_SWISH(T#195) -> [T#196]
#   Op#66 DEPTHWISE_CONV_2D(T#196, T#116, T#37) -> [T#197]
#   Op#67 HARD_SWISH(T#197) -> [T#198]
#   Op#68 MEAN(T#198, T#20) -> [T#199]
#   Op#69 CONV_2D(T#199, T#70, T#8) -> [T#200]
#   Op#70 CONV_2D(T#200, T#71, T#14) -> [T#201]
#   Op#71 MUL(T#201, T#10) -> [T#202]
#   Op#72 MUL(T#198, T#202) -> [T#203]
#   Op#73 CONV_2D(T#203, T#72, T#117) -> [T#204]
#   Op#74 CONV_2D(T#204, T#73, T#118) -> [T#205]
#   Op#75 HARD_SWISH(T#205) -> [T#206]
#   Op#76 DEPTHWISE_CONV_2D(T#206, T#119, T#38) -> [T#207]
#   Op#77 HARD_SWISH(T#207) -> [T#208]
#   Op#78 MEAN(T#208, T#20) -> [T#209]
#   Op#79 CONV_2D(T#209, T#74, T#7) -> [T#210]
#   Op#80 CONV_2D(T#210, T#75, T#15) -> [T#211]
#   Op#81 MUL(T#211, T#10) -> [T#212]
#   Op#82 MUL(T#208, T#212) -> [T#213]
#   Op#83 CONV_2D(T#213, T#76, T#120) -> [T#214]
#   Op#84 ADD(T#204, T#214) -> [T#215]
#   Op#85 CONV_2D(T#215, T#77, T#121) -> [T#216]
#   Op#86 HARD_SWISH(T#216) -> [T#217]
#   Op#87 PAD(T#217, T#21) -> [T#218]
#   Op#88 DEPTHWISE_CONV_2D(T#218, T#122, T#39) -> [T#219]
#   Op#89 HARD_SWISH(T#219) -> [T#220]
#   Op#90 MEAN(T#220, T#20) -> [T#221]
#   Op#91 CONV_2D(T#221, T#78, T#6) -> [T#222]
#   Op#92 CONV_2D(T#222, T#79, T#16) -> [T#223]
#   Op#93 MUL(T#223, T#10) -> [T#224]
#   Op#94 MUL(T#220, T#224) -> [T#225]
#   Op#95 CONV_2D(T#225, T#80, T#123) -> [T#226]
#   Op#96 CONV_2D(T#226, T#81, T#124) -> [T#227]
#   Op#97 HARD_SWISH(T#227) -> [T#228]
#   Op#98 DEPTHWISE_CONV_2D(T#228, T#125, T#40) -> [T#229]
#   Op#99 HARD_SWISH(T#229) -> [T#230]
#   Op#100 MEAN(T#230, T#20) -> [T#231]
#   Op#101 CONV_2D(T#231, T#82, T#5) -> [T#232]
#   Op#102 CONV_2D(T#232, T#83, T#17) -> [T#233]
#   Op#103 MUL(T#233, T#10) -> [T#234]
#   Op#104 MUL(T#230, T#234) -> [T#235]
#   Op#105 CONV_2D(T#235, T#84, T#126) -> [T#236]
#   Op#106 ADD(T#226, T#236) -> [T#237]
#   Op#107 CONV_2D(T#237, T#85, T#127) -> [T#238]
#   Op#108 HARD_SWISH(T#238) -> [T#239]
#   Op#109 DEPTHWISE_CONV_2D(T#239, T#128, T#41) -> [T#240]
#   Op#110 HARD_SWISH(T#240) -> [T#241]
#   Op#111 MEAN(T#241, T#20) -> [T#242]
#   Op#112 CONV_2D(T#242, T#86, T#4) -> [T#243]
#   Op#113 CONV_2D(T#243, T#87, T#18) -> [T#244]
#   Op#114 MUL(T#244, T#10) -> [T#245]
#   Op#115 MUL(T#241, T#245) -> [T#246]
#   Op#116 CONV_2D(T#246, T#88, T#129) -> [T#247]
#   Op#117 ADD(T#237, T#247) -> [T#248]
#   Op#118 CONV_2D(T#248, T#89, T#130) -> [T#249]
#   Op#119 HARD_SWISH(T#249) -> [T#250]
#   Op#120 MEAN(T#250, T#20) -> [T#251]
#   Op#121 FULLY_CONNECTED(T#251, T#42, T#9) -> [T#252]
#   Op#122 LOGISTIC(T#252) -> [T#253]
#
# Tensors of Subgraph#0
#   T#0(serving_default_MobilenetV3large_input:0) shape_signature:[-1, 224, 224, 3], type:FLOAT32
#   T#1(expanded_conv_5/squeeze_excite/Conv/bias) shape:[32], type:FLOAT32 RO 128 bytes
#   T#2(expanded_conv_4/squeeze_excite/Conv/bias) shape:[32], type:FLOAT32 RO 128 bytes
#   T#3(expanded_conv_3/squeeze_excite/Conv/bias) shape:[24], type:FLOAT32 RO 96 bytes
#   T#4(expanded_conv_14/squeeze_excite/Conv/bias) shape:[240], type:FLOAT32 RO 960 bytes
#   T#5(expanded_conv_13/squeeze_excite/Conv/bias) shape:[240], type:FLOAT32 RO 960 bytes
#   T#6(expanded_conv_12/squeeze_excite/Conv/bias) shape:[168], type:FLOAT32 RO 672 bytes
#   T#7(expanded_conv_11/squeeze_excite/Conv/bias) shape:[168], type:FLOAT32 RO 672 bytes
#   T#8(expanded_conv_10/squeeze_excite/Conv/bias) shape:[120], type:FLOAT32 RO 480 bytes
#   T#9(dense/bias) shape:[1], type:FLOAT32 RO 4 bytes
#   T#10(sequential/MobilenetV3large/tf.math.multiply_28/Mul/y) shape:[], type:FLOAT32 RO 4 bytes
#   T#11(sequential/MobilenetV3large/re_lu_47/Relu6;sequential/MobilenetV3large/tf.__operators__.add_29/AddV2;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D;expanded_conv_3/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[72], type:FLOAT32 RO 288 bytes
#   T#12(sequential/MobilenetV3large/re_lu_50/Relu6;sequential/MobilenetV3large/tf.__operators__.add_30/AddV2;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv_1/Conv2D;expanded_conv_4/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[120], type:FLOAT32 RO 480 bytes
#   T#13(sequential/MobilenetV3large/re_lu_53/Relu6;sequential/MobilenetV3large/tf.__operators__.add_31/AddV2;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv_1/Conv2D;expanded_conv_5/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[120], type:FLOAT32 RO 480 bytes
#   T#14(sequential/MobilenetV3large/re_lu_64/Relu6;sequential/MobilenetV3large/tf.__operators__.add_42/AddV2;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D;expanded_conv_10/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[480], type:FLOAT32 RO 1920 bytes
#   T#15(sequential/MobilenetV3large/re_lu_67/Relu6;sequential/MobilenetV3large/tf.__operators__.add_45/AddV2;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv_1/Conv2D;expanded_conv_11/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#16(sequential/MobilenetV3large/re_lu_70/Relu6;sequential/MobilenetV3large/tf.__operators__.add_48/AddV2;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;expanded_conv_12/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#17(sequential/MobilenetV3large/re_lu_73/Relu6;sequential/MobilenetV3large/tf.__operators__.add_51/AddV2;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv_1/Conv2D;expanded_conv_13/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#18(sequential/MobilenetV3large/re_lu_76/Relu6;sequential/MobilenetV3large/tf.__operators__.add_54/AddV2;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv_1/Conv2D;expanded_conv_14/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#19(sequential/MobilenetV3large/expanded_conv_1/depthwise/pad/Pad/paddings) shape:[4, 2], type:INT32 RO 32 bytes
#   T#20(sequential/MobilenetV3large/avg_pool/Mean/reduction_indices) shape:[2], type:INT32 RO 8 bytes
#   T#21(sequential/MobilenetV3large/expanded_conv_12/depthwise/pad/Pad/paddings) shape:[4, 2], type:INT32 RO 32 bytes
#   T#22(sequential/MobilenetV3large/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3) shape:[16], type:FLOAT32 RO 64 bytes
#   T#23(sequential/MobilenetV3large/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3) shape:[64], type:FLOAT32 RO 256 bytes
#   T#24(sequential/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3) shape:[64], type:FLOAT32 RO 256 bytes
#   T#25(sequential/MobilenetV3large/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3) shape:[72], type:FLOAT32 RO 288 bytes
#   T#26(sequential/MobilenetV3large/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3) shape:[72], type:FLOAT32 RO 288 bytes
#   T#27(sequential/MobilenetV3large/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3) shape:[72], type:FLOAT32 RO 288 bytes
#   T#28(sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3) shape:[72], type:FLOAT32 RO 288 bytes
#   T#29(sequential/MobilenetV3large/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes
#   T#30(sequential/MobilenetV3large/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes
#   T#31(sequential/MobilenetV3large/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes
#   T#32(sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes
#   T#33(sequential/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3) shape:[240], type:FLOAT32 RO 960 bytes
#   T#34(sequential/MobilenetV3large/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3) shape:[200], type:FLOAT32 RO 800 bytes
#   T#35(sequential/MobilenetV3large/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3) shape:[184], type:FLOAT32 RO 736 bytes
#   T#36(sequential/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3) shape:[184], type:FLOAT32 RO 736 bytes
#   T#37(sequential/MobilenetV3large/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3) shape:[480], type:FLOAT32 RO 1920 bytes
#   T#38(sequential/MobilenetV3large/expanded_conv_11/depthwise/BatchNorm/FusedBatchNormV3) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#39(sequential/MobilenetV3large/expanded_conv_12/depthwise/BatchNorm/FusedBatchNormV3) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#40(sequential/MobilenetV3large/expanded_conv_13/depthwise/BatchNorm/FusedBatchNormV3) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#41(sequential/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#42(sequential/dense/MatMul) shape:[1, 960], type:FLOAT32 RO 3840 bytes
#   T#43(sequential/MobilenetV3large/Conv/Conv2D) shape:[16, 3, 3, 3], type:FLOAT32 RO 1728 bytes
#   T#44(sequential/MobilenetV3large/expanded_conv/project/Conv2D) shape:[16, 1, 1, 16], type:FLOAT32 RO 1024 bytes
#   T#45(sequential/MobilenetV3large/expanded_conv_1/expand/Conv2D) shape:[64, 1, 1, 16], type:FLOAT32 RO 4096 bytes
#   T#46(sequential/MobilenetV3large/expanded_conv_1/project/Conv2D) shape:[24, 1, 1, 64], type:FLOAT32 RO 6144 bytes
#   T#47(sequential/MobilenetV3large/expanded_conv_2/expand/Conv2D) shape:[72, 1, 1, 24], type:FLOAT32 RO 6912 bytes
#   T#48(sequential/MobilenetV3large/expanded_conv_2/project/Conv2D) shape:[24, 1, 1, 72], type:FLOAT32 RO 6912 bytes
#   T#49(sequential/MobilenetV3large/expanded_conv_3/expand/Conv2D) shape:[72, 1, 1, 24], type:FLOAT32 RO 6912 bytes
#   T#50(sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D) shape:[24, 1, 1, 72], type:FLOAT32 RO 6912 bytes
#   T#51(sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D) shape:[72, 1, 1, 24], type:FLOAT32 RO 6912 bytes
#   T#52(sequential/MobilenetV3large/expanded_conv_3/project/Conv2D) shape:[40, 1, 1, 72], type:FLOAT32 RO 11520 bytes
#   T#53(sequential/MobilenetV3large/expanded_conv_4/expand/Conv2D) shape:[120, 1, 1, 40], type:FLOAT32 RO 19200 bytes
#   T#54(sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv/Conv2D) shape:[32, 1, 1, 120], type:FLOAT32 RO 15360 bytes
#   T#55(sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv_1/Conv2D) shape:[120, 1, 1, 32], type:FLOAT32 RO 15360 bytes
#   T#56(sequential/MobilenetV3large/expanded_conv_4/project/Conv2D) shape:[40, 1, 1, 120], type:FLOAT32 RO 19200 bytes
#   T#57(sequential/MobilenetV3large/expanded_conv_5/expand/Conv2D) shape:[120, 1, 1, 40], type:FLOAT32 RO 19200 bytes
#   T#58(sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv/Conv2D) shape:[32, 1, 1, 120], type:FLOAT32 RO 15360 bytes
#   T#59(sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv_1/Conv2D) shape:[120, 1, 1, 32], type:FLOAT32 RO 15360 bytes
#   T#60(sequential/MobilenetV3large/expanded_conv_5/project/Conv2D) shape:[40, 1, 1, 120], type:FLOAT32 RO 19200 bytes
#   T#61(sequential/MobilenetV3large/expanded_conv_6/expand/Conv2D) shape:[240, 1, 1, 40], type:FLOAT32 RO 38400 bytes
#   T#62(sequential/MobilenetV3large/expanded_conv_6/project/Conv2D) shape:[80, 1, 1, 240], type:FLOAT32 RO 76800 bytes
#   T#63(sequential/MobilenetV3large/expanded_conv_7/expand/Conv2D) shape:[200, 1, 1, 80], type:FLOAT32 RO 64000 bytes
#   T#64(sequential/MobilenetV3large/expanded_conv_7/project/Conv2D) shape:[80, 1, 1, 200], type:FLOAT32 RO 64000 bytes
#   T#65(sequential/MobilenetV3large/expanded_conv_8/expand/Conv2D) shape:[184, 1, 1, 80], type:FLOAT32 RO 58880 bytes
#   T#66(sequential/MobilenetV3large/expanded_conv_8/project/Conv2D) shape:[80, 1, 1, 184], type:FLOAT32 RO 58880 bytes
#   T#67(sequential/MobilenetV3large/expanded_conv_9/expand/Conv2D) shape:[184, 1, 1, 80], type:FLOAT32 RO 58880 bytes
#   T#68(sequential/MobilenetV3large/expanded_conv_9/project/Conv2D) shape:[80, 1, 1, 184], type:FLOAT32 RO 58880 bytes
#   T#69(sequential/MobilenetV3large/expanded_conv_10/expand/Conv2D) shape:[480, 1, 1, 80], type:FLOAT32 RO 153600 bytes
#   T#70(sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D) shape:[120, 1, 1, 480], type:FLOAT32 RO 230400 bytes
#   T#71(sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D) shape:[480, 1, 1, 120], type:FLOAT32 RO 230400 bytes
#   T#72(sequential/MobilenetV3large/expanded_conv_10/project/Conv2D) shape:[112, 1, 1, 480], type:FLOAT32 RO 215040 bytes
#   T#73(sequential/MobilenetV3large/expanded_conv_11/expand/Conv2D) shape:[672, 1, 1, 112], type:FLOAT32 RO 301056 bytes
#   T#74(sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv/Conv2D) shape:[168, 1, 1, 672], type:FLOAT32 RO 451584 bytes
#   T#75(sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv_1/Conv2D) shape:[672, 1, 1, 168], type:FLOAT32 RO 451584 bytes
#   T#76(sequential/MobilenetV3large/expanded_conv_11/project/Conv2D) shape:[112, 1, 1, 672], type:FLOAT32 RO 301056 bytes
#   T#77(sequential/MobilenetV3large/expanded_conv_12/expand/Conv2D) shape:[672, 1, 1, 112], type:FLOAT32 RO 301056 bytes
#   T#78(sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv/Conv2D) shape:[168, 1, 1, 672], type:FLOAT32 RO 451584 bytes
#   T#79(sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D) shape:[672, 1, 1, 168], type:FLOAT32 RO 451584 bytes
#   T#80(sequential/MobilenetV3large/expanded_conv_12/project/Conv2D) shape:[160, 1, 1, 672], type:FLOAT32 RO 430080 bytes
#   T#81(sequential/MobilenetV3large/expanded_conv_13/expand/Conv2D) shape:[960, 1, 1, 160], type:FLOAT32 RO 614400 bytes
#   T#82(sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv/Conv2D) shape:[240, 1, 1, 960], type:FLOAT32 RO 921600 bytes
#   T#83(sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv_1/Conv2D) shape:[960, 1, 1, 240], type:FLOAT32 RO 921600 bytes
#   T#84(sequential/MobilenetV3large/expanded_conv_13/project/Conv2D) shape:[160, 1, 1, 960], type:FLOAT32 RO 614400 bytes
#   T#85(sequential/MobilenetV3large/expanded_conv_14/expand/Conv2D) shape:[960, 1, 1, 160], type:FLOAT32 RO 614400 bytes
#   T#86(sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D) shape:[240, 1, 1, 960], type:FLOAT32 RO 921600 bytes
#   T#87(sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv_1/Conv2D) shape:[960, 1, 1, 240], type:FLOAT32 RO 921600 bytes
#   T#88(sequential/MobilenetV3large/expanded_conv_14/project/Conv2D) shape:[160, 1, 1, 960], type:FLOAT32 RO 614400 bytes
#   T#89(sequential/MobilenetV3large/Conv_1/Conv2D) shape:[960, 1, 1, 160], type:FLOAT32 RO 614400 bytes
#   T#90(sequential/MobilenetV3large/Conv/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/project/Conv2D;sequential/MobilenetV3large/Conv/Conv2D) shape:[16], type:FLOAT32 RO 64 bytes
#   T#91(sequential/MobilenetV3large/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv/project/Conv2D) shape:[1, 3, 3, 16], type:FLOAT32 RO 576 bytes
#   T#92(sequential/MobilenetV3large/expanded_conv/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/project/Conv2D) shape:[16], type:FLOAT32 RO 64 bytes
#   T#93(sequential/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_1/depthwise/depthwise) shape:[1, 3, 3, 64], type:FLOAT32 RO 2304 bytes
#   T#94(sequential/MobilenetV3large/expanded_conv_1/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_1/project/Conv2D) shape:[24], type:FLOAT32 RO 96 bytes
#   T#95(sequential/MobilenetV3large/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_2/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D) shape:[1, 3, 3, 72], type:FLOAT32 RO 2592 bytes
#   T#96(sequential/MobilenetV3large/expanded_conv_2/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_2/project/Conv2D) shape:[24], type:FLOAT32 RO 96 bytes
#   T#97(sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D) shape:[1, 5, 5, 72], type:FLOAT32 RO 7200 bytes
#   T#98(sequential/MobilenetV3large/expanded_conv_3/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D;sequential/MobilenetV3large/expanded_conv_3/project/Conv2D) shape:[40], type:FLOAT32 RO 160 bytes
#   T#99(sequential/MobilenetV3large/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_4/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D) shape:[1, 5, 5, 120], type:FLOAT32 RO 12000 bytes
#   T#100(sequential/MobilenetV3large/expanded_conv_4/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D;sequential/MobilenetV3large/expanded_conv_4/project/Conv2D) shape:[40], type:FLOAT32 RO 160 bytes
#   T#101(sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D) shape:[1, 5, 5, 120], type:FLOAT32 RO 12000 bytes
#   T#102(sequential/MobilenetV3large/expanded_conv_5/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D) shape:[40], type:FLOAT32 RO 160 bytes
#   T#103(sequential/MobilenetV3large/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_6/expand/Conv2D) shape:[240], type:FLOAT32 RO 960 bytes
#   T#104(sequential/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_6/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D) shape:[1, 3, 3, 240], type:FLOAT32 RO 8640 bytes
#   T#105(sequential/MobilenetV3large/expanded_conv_6/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_6/project/Conv2D) shape:[80], type:FLOAT32 RO 320 bytes
#   T#106(sequential/MobilenetV3large/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_7/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_7/expand/Conv2D) shape:[200], type:FLOAT32 RO 800 bytes
#   T#107(sequential/MobilenetV3large/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_7/depthwise/depthwise) shape:[1, 3, 3, 200], type:FLOAT32 RO 7200 bytes
#   T#108(sequential/MobilenetV3large/expanded_conv_7/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_7/project/Conv2D) shape:[80], type:FLOAT32 RO 320 bytes
#   T#109(sequential/MobilenetV3large/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_8/expand/Conv2D) shape:[184], type:FLOAT32 RO 736 bytes
#   T#110(sequential/MobilenetV3large/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_8/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise) shape:[1, 3, 3, 184], type:FLOAT32 RO 6624 bytes
#   T#111(sequential/MobilenetV3large/expanded_conv_8/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_8/project/Conv2D) shape:[80], type:FLOAT32 RO 320 bytes
#   T#112(sequential/MobilenetV3large/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_9/expand/Conv2D) shape:[184], type:FLOAT32 RO 736 bytes
#   T#113(sequential/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise) shape:[1, 3, 3, 184], type:FLOAT32 RO 6624 bytes
#   T#114(sequential/MobilenetV3large/expanded_conv_9/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D) shape:[80], type:FLOAT32 RO 320 bytes
#   T#115(sequential/MobilenetV3large/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_10/expand/Conv2D) shape:[480], type:FLOAT32 RO 1920 bytes
#   T#116(sequential/MobilenetV3large/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_10/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D) shape:[1, 3, 3, 480], type:FLOAT32 RO 17280 bytes
#   T#117(sequential/MobilenetV3large/expanded_conv_10/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/project/Conv2D;sequential/MobilenetV3large/expanded_conv_10/project/Conv2D) shape:[112], type:FLOAT32 RO 448 bytes
#   T#118(sequential/MobilenetV3large/expanded_conv_11/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_11/expand/Conv2D) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#119(sequential/MobilenetV3large/expanded_conv_11/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D) shape:[1, 3, 3, 672], type:FLOAT32 RO 24192 bytes
#   T#120(sequential/MobilenetV3large/expanded_conv_11/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/project/Conv2D) shape:[112], type:FLOAT32 RO 448 bytes
#   T#121(sequential/MobilenetV3large/expanded_conv_12/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_12/expand/Conv2D) shape:[672], type:FLOAT32 RO 2688 bytes
#   T#122(sequential/MobilenetV3large/expanded_conv_12/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D) shape:[1, 5, 5, 672], type:FLOAT32 RO 67200 bytes
#   T#123(sequential/MobilenetV3large/expanded_conv_12/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D;sequential/MobilenetV3large/expanded_conv_12/project/Conv2D) shape:[160], type:FLOAT32 RO 640 bytes
#   T#124(sequential/MobilenetV3large/expanded_conv_13/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_13/expand/Conv2D) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#125(sequential/MobilenetV3large/expanded_conv_13/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_13/depthwise/depthwise;sequential/MobilenetV3large/Conv_1/Conv2D) shape:[1, 5, 5, 960], type:FLOAT32 RO 96000 bytes
#   T#126(sequential/MobilenetV3large/expanded_conv_13/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D;sequential/MobilenetV3large/expanded_conv_13/project/Conv2D) shape:[160], type:FLOAT32 RO 640 bytes
#   T#127(sequential/MobilenetV3large/expanded_conv_14/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_14/expand/Conv2D) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#128(sequential/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/depthwise/depthwise;sequential/MobilenetV3large/Conv_1/Conv2D) shape:[1, 5, 5, 960], type:FLOAT32 RO 96000 bytes
#   T#129(sequential/MobilenetV3large/expanded_conv_14/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D) shape:[160], type:FLOAT32 RO 640 bytes
#   T#130(sequential/MobilenetV3large/Conv_1/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D) shape:[960], type:FLOAT32 RO 3840 bytes
#   T#131(sequential/MobilenetV3large/Conv/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/project/Conv2D;sequential/MobilenetV3large/Conv/Conv2D1) shape_signature:[-1, 112, 112, 16], type:FLOAT32
#   T#132(sequential/MobilenetV3large/multiply_20/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_39/Relu6;sequential/MobilenetV3large/tf.__operators__.add_28/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_28/Mul) shape_signature:[-1, 112, 112, 16], type:FLOAT32
#   T#133(sequential/MobilenetV3large/re_lu_40/Relu;sequential/MobilenetV3large/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv/project/Conv2D) shape_signature:[-1, 112, 112, 16], type:FLOAT32
#   T#134(sequential/MobilenetV3large/expanded_conv/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv/project/Conv2D1) shape_signature:[-1, 112, 112, 16], type:FLOAT32
#   T#135(sequential/MobilenetV3large/expanded_conv/Add/add) shape_signature:[-1, 112, 112, 16], type:FLOAT32
#   T#136(sequential/MobilenetV3large/re_lu_41/Relu;sequential/MobilenetV3large/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_1/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_1/expand/Conv2D) shape_signature:[-1, 112, 112, 64], type:FLOAT32
#   T#137(sequential/MobilenetV3large/expanded_conv_1/depthwise/pad/Pad) shape_signature:[-1, 113, 113, 64], type:FLOAT32
#   T#138(sequential/MobilenetV3large/re_lu_42/Relu;sequential/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_1/depthwise/depthwise) shape_signature:[-1, 56, 56, 64], type:FLOAT32
#   T#139(sequential/MobilenetV3large/expanded_conv_1/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_1/project/Conv2D1) shape_signature:[-1, 56, 56, 24], type:FLOAT32
#   T#140(sequential/MobilenetV3large/re_lu_43/Relu;sequential/MobilenetV3large/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_2/expand/Conv2D) shape_signature:[-1, 56, 56, 72], type:FLOAT32
#   T#141(sequential/MobilenetV3large/re_lu_44/Relu;sequential/MobilenetV3large/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_2/depthwise/depthwise) shape_signature:[-1, 56, 56, 72], type:FLOAT32
#   T#142(sequential/MobilenetV3large/expanded_conv_2/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_2/project/Conv2D1) shape_signature:[-1, 56, 56, 24], type:FLOAT32
#   T#143(sequential/MobilenetV3large/expanded_conv_2/Add/add) shape_signature:[-1, 56, 56, 24], type:FLOAT32
#   T#144(sequential/MobilenetV3large/re_lu_45/Relu;sequential/MobilenetV3large/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_3/expand/Conv2D) shape_signature:[-1, 56, 56, 72], type:FLOAT32
#   T#145(sequential/MobilenetV3large/expanded_conv_3/depthwise/pad/Pad) shape_signature:[-1, 59, 59, 72], type:FLOAT32
#   T#146(sequential/MobilenetV3large/re_lu_46/Relu;sequential/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_3/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D) shape_signature:[-1, 28, 28, 72], type:FLOAT32
#   T#147(sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 72], type:FLOAT32
#   T#148(sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv/Conv2D;expanded_conv_3/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 24], type:FLOAT32
#   T#149(sequential/MobilenetV3large/re_lu_47/Relu6;sequential/MobilenetV3large/tf.__operators__.add_29/AddV2;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Conv_1/Conv2D;expanded_conv_3/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 72], type:FLOAT32
#   T#150(sequential/MobilenetV3large/tf.math.multiply_29/Mul) shape_signature:[-1, 1, 1, 72], type:FLOAT32
#   T#151(sequential/MobilenetV3large/expanded_conv_3/squeeze_excite/Mul/mul) shape_signature:[-1, 28, 28, 72], type:FLOAT32
#   T#152(sequential/MobilenetV3large/expanded_conv_3/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D;sequential/MobilenetV3large/expanded_conv_3/project/Conv2D1) shape_signature:[-1, 28, 28, 40], type:FLOAT32
#   T#153(sequential/MobilenetV3large/re_lu_48/Relu;sequential/MobilenetV3large/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_4/expand/Conv2D) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#154(sequential/MobilenetV3large/re_lu_49/Relu;sequential/MobilenetV3large/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_4/depthwise/depthwise) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#155(sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#156(sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv/Conv2D;expanded_conv_4/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 32], type:FLOAT32
#   T#157(sequential/MobilenetV3large/re_lu_50/Relu6;sequential/MobilenetV3large/tf.__operators__.add_30/AddV2;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Conv_1/Conv2D;expanded_conv_4/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#158(sequential/MobilenetV3large/tf.math.multiply_30/Mul) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#159(sequential/MobilenetV3large/expanded_conv_4/squeeze_excite/Mul/mul) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#160(sequential/MobilenetV3large/expanded_conv_4/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D;sequential/MobilenetV3large/expanded_conv_4/project/Conv2D1) shape_signature:[-1, 28, 28, 40], type:FLOAT32
#   T#161(sequential/MobilenetV3large/expanded_conv_4/Add/add) shape_signature:[-1, 28, 28, 40], type:FLOAT32
#   T#162(sequential/MobilenetV3large/re_lu_51/Relu;sequential/MobilenetV3large/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_5/expand/Conv2D) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#163(sequential/MobilenetV3large/re_lu_52/Relu;sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#164(sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#165(sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv/Conv2D;expanded_conv_5/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 32], type:FLOAT32
#   T#166(sequential/MobilenetV3large/re_lu_53/Relu6;sequential/MobilenetV3large/tf.__operators__.add_31/AddV2;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Conv_1/Conv2D;expanded_conv_5/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#167(sequential/MobilenetV3large/tf.math.multiply_31/Mul) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#168(sequential/MobilenetV3large/expanded_conv_5/squeeze_excite/Mul/mul) shape_signature:[-1, 28, 28, 120], type:FLOAT32
#   T#169(sequential/MobilenetV3large/expanded_conv_5/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/project/Conv2D1) shape_signature:[-1, 28, 28, 40], type:FLOAT32
#   T#170(sequential/MobilenetV3large/expanded_conv_5/Add/add) shape_signature:[-1, 28, 28, 40], type:FLOAT32
#   T#171(sequential/MobilenetV3large/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_6/expand/Conv2D1) shape_signature:[-1, 28, 28, 240], type:FLOAT32
#   T#172(sequential/MobilenetV3large/multiply_21/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_54/Relu6;sequential/MobilenetV3large/tf.__operators__.add_32/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_32/Mul) shape_signature:[-1, 28, 28, 240], type:FLOAT32
#   T#173(sequential/MobilenetV3large/expanded_conv_6/depthwise/pad/Pad) shape_signature:[-1, 29, 29, 240], type:FLOAT32
#   T#174(sequential/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_6/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D1) shape_signature:[-1, 14, 14, 240], type:FLOAT32
#   T#175(sequential/MobilenetV3large/multiply_22/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_55/Relu6;sequential/MobilenetV3large/tf.__operators__.add_33/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_33/Mul) shape_signature:[-1, 14, 14, 240], type:FLOAT32
#   T#176(sequential/MobilenetV3large/expanded_conv_6/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_6/project/Conv2D1) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#177(sequential/MobilenetV3large/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_7/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_7/expand/Conv2D1) shape_signature:[-1, 14, 14, 200], type:FLOAT32
#   T#178(sequential/MobilenetV3large/multiply_23/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_56/Relu6;sequential/MobilenetV3large/tf.__operators__.add_34/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_34/Mul) shape_signature:[-1, 14, 14, 200], type:FLOAT32
#   T#179(sequential/MobilenetV3large/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_7/depthwise/depthwise1) shape_signature:[-1, 14, 14, 200], type:FLOAT32
#   T#180(sequential/MobilenetV3large/multiply_24/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_57/Relu6;sequential/MobilenetV3large/tf.__operators__.add_35/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_35/Mul) shape_signature:[-1, 14, 14, 200], type:FLOAT32
#   T#181(sequential/MobilenetV3large/expanded_conv_7/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_7/project/Conv2D1) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#182(sequential/MobilenetV3large/expanded_conv_7/Add/add) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#183(sequential/MobilenetV3large/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_8/expand/Conv2D1) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#184(sequential/MobilenetV3large/multiply_25/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_58/Relu6;sequential/MobilenetV3large/tf.__operators__.add_36/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_36/Mul) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#185(sequential/MobilenetV3large/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_8/depthwise/depthwise) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#186(sequential/MobilenetV3large/multiply_26/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_59/Relu6;sequential/MobilenetV3large/tf.__operators__.add_37/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_37/Mul) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#187(sequential/MobilenetV3large/expanded_conv_8/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D;sequential/MobilenetV3large/expanded_conv_8/project/Conv2D1) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#188(sequential/MobilenetV3large/expanded_conv_8/Add/add) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#189(sequential/MobilenetV3large/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_9/expand/Conv2D1) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#190(sequential/MobilenetV3large/multiply_27/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_60/Relu6;sequential/MobilenetV3large/tf.__operators__.add_38/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_38/Mul) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#191(sequential/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/depthwise/depthwise1) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#192(sequential/MobilenetV3large/multiply_28/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_61/Relu6;sequential/MobilenetV3large/tf.__operators__.add_39/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_39/Mul) shape_signature:[-1, 14, 14, 184], type:FLOAT32
#   T#193(sequential/MobilenetV3large/expanded_conv_9/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_9/project/Conv2D1) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#194(sequential/MobilenetV3large/expanded_conv_9/Add/add) shape_signature:[-1, 14, 14, 80], type:FLOAT32
#   T#195(sequential/MobilenetV3large/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_10/expand/Conv2D1) shape_signature:[-1, 14, 14, 480], type:FLOAT32
#   T#196(sequential/MobilenetV3large/multiply_29/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_62/Relu6;sequential/MobilenetV3large/tf.__operators__.add_40/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_40/Mul) shape_signature:[-1, 14, 14, 480], type:FLOAT32
#   T#197(sequential/MobilenetV3large/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_10/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D1) shape_signature:[-1, 14, 14, 480], type:FLOAT32
#   T#198(sequential/MobilenetV3large/multiply_30/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_63/Relu6;sequential/MobilenetV3large/tf.__operators__.add_41/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_41/Mul) shape_signature:[-1, 14, 14, 480], type:FLOAT32
#   T#199(sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 480], type:FLOAT32
#   T#200(sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_5/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv/Conv2D;expanded_conv_10/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 120], type:FLOAT32
#   T#201(sequential/MobilenetV3large/re_lu_64/Relu6;sequential/MobilenetV3large/tf.__operators__.add_42/AddV2;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Conv_1/Conv2D;expanded_conv_10/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 480], type:FLOAT32
#   T#202(sequential/MobilenetV3large/tf.math.multiply_42/Mul) shape_signature:[-1, 1, 1, 480], type:FLOAT32
#   T#203(sequential/MobilenetV3large/expanded_conv_10/squeeze_excite/Mul/mul) shape_signature:[-1, 14, 14, 480], type:FLOAT32
#   T#204(sequential/MobilenetV3large/expanded_conv_10/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/project/Conv2D;sequential/MobilenetV3large/expanded_conv_10/project/Conv2D1) shape_signature:[-1, 14, 14, 112], type:FLOAT32
#   T#205(sequential/MobilenetV3large/expanded_conv_11/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_11/expand/Conv2D1) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#206(sequential/MobilenetV3large/multiply_31/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_65/Relu6;sequential/MobilenetV3large/tf.__operators__.add_43/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_43/Mul) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#207(sequential/MobilenetV3large/expanded_conv_11/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D1) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#208(sequential/MobilenetV3large/multiply_32/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_66/Relu6;sequential/MobilenetV3large/tf.__operators__.add_44/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_44/Mul) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#209(sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#210(sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv/Conv2D;expanded_conv_11/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 168], type:FLOAT32
#   T#211(sequential/MobilenetV3large/re_lu_67/Relu6;sequential/MobilenetV3large/tf.__operators__.add_45/AddV2;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Conv_1/Conv2D;expanded_conv_11/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#212(sequential/MobilenetV3large/tf.math.multiply_45/Mul) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#213(sequential/MobilenetV3large/expanded_conv_11/squeeze_excite/Mul/mul) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#214(sequential/MobilenetV3large/expanded_conv_11/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_11/project/Conv2D1) shape_signature:[-1, 14, 14, 112], type:FLOAT32
#   T#215(sequential/MobilenetV3large/expanded_conv_11/Add/add) shape_signature:[-1, 14, 14, 112], type:FLOAT32
#   T#216(sequential/MobilenetV3large/expanded_conv_12/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_12/expand/Conv2D1) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#217(sequential/MobilenetV3large/multiply_33/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_68/Relu6;sequential/MobilenetV3large/tf.__operators__.add_46/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_46/Mul) shape_signature:[-1, 14, 14, 672], type:FLOAT32
#   T#218(sequential/MobilenetV3large/expanded_conv_12/depthwise/pad/Pad) shape_signature:[-1, 17, 17, 672], type:FLOAT32
#   T#219(sequential/MobilenetV3large/expanded_conv_12/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_12/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D1) shape_signature:[-1, 7, 7, 672], type:FLOAT32
#   T#220(sequential/MobilenetV3large/multiply_34/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_69/Relu6;sequential/MobilenetV3large/tf.__operators__.add_47/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_47/Mul) shape_signature:[-1, 7, 7, 672], type:FLOAT32
#   T#221(sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#222(sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv/Conv2D;expanded_conv_12/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 168], type:FLOAT32
#   T#223(sequential/MobilenetV3large/re_lu_70/Relu6;sequential/MobilenetV3large/tf.__operators__.add_48/AddV2;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Conv_1/Conv2D;expanded_conv_12/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#224(sequential/MobilenetV3large/tf.math.multiply_48/Mul) shape_signature:[-1, 1, 1, 672], type:FLOAT32
#   T#225(sequential/MobilenetV3large/expanded_conv_12/squeeze_excite/Mul/mul) shape_signature:[-1, 7, 7, 672], type:FLOAT32
#   T#226(sequential/MobilenetV3large/expanded_conv_12/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D;sequential/MobilenetV3large/expanded_conv_12/project/Conv2D1) shape_signature:[-1, 7, 7, 160], type:FLOAT32
#   T#227(sequential/MobilenetV3large/expanded_conv_13/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_13/expand/Conv2D1) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#228(sequential/MobilenetV3large/multiply_35/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_71/Relu6;sequential/MobilenetV3large/tf.__operators__.add_49/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_49/Mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#229(sequential/MobilenetV3large/expanded_conv_13/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/depthwise/depthwise;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_13/depthwise/depthwise) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#230(sequential/MobilenetV3large/multiply_36/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_72/Relu6;sequential/MobilenetV3large/tf.__operators__.add_50/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_50/Mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#231(sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#232(sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_6/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv/Conv2D;expanded_conv_13/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 240], type:FLOAT32
#   T#233(sequential/MobilenetV3large/re_lu_73/Relu6;sequential/MobilenetV3large/tf.__operators__.add_51/AddV2;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Conv_1/Conv2D;expanded_conv_13/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#234(sequential/MobilenetV3large/tf.math.multiply_51/Mul) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#235(sequential/MobilenetV3large/expanded_conv_13/squeeze_excite/Mul/mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#236(sequential/MobilenetV3large/expanded_conv_13/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D;sequential/MobilenetV3large/expanded_conv_13/project/Conv2D1) shape_signature:[-1, 7, 7, 160], type:FLOAT32
#   T#237(sequential/MobilenetV3large/expanded_conv_13/Add/add) shape_signature:[-1, 7, 7, 160], type:FLOAT32
#   T#238(sequential/MobilenetV3large/expanded_conv_14/expand/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_14/expand/Conv2D1) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#239(sequential/MobilenetV3large/multiply_37/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_74/Relu6;sequential/MobilenetV3large/tf.__operators__.add_52/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_52/Mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#240(sequential/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/depthwise/depthwise;sequential/MobilenetV3large/Conv_1/Conv2D1) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#241(sequential/MobilenetV3large/multiply_38/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_75/Relu6;sequential/MobilenetV3large/tf.__operators__.add_53/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_53/Mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#242(sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/AvgPool/Mean) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#243(sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Relu/Relu;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/BiasAdd;sequential/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_6/depthwise/depthwise;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv/Conv2D;expanded_conv_14/squeeze_excite/Conv/bias) shape_signature:[-1, 1, 1, 240], type:FLOAT32
#   T#244(sequential/MobilenetV3large/re_lu_76/Relu6;sequential/MobilenetV3large/tf.__operators__.add_54/AddV2;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv_1/BiasAdd;sequential/MobilenetV3large/Conv_1/Conv2D;sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Conv_1/Conv2D;expanded_conv_14/squeeze_excite/Conv_1/bias;sequential/MobilenetV3large/tf.__operators__.add_28/y1) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#245(sequential/MobilenetV3large/tf.math.multiply_54/Mul) shape_signature:[-1, 1, 1, 960], type:FLOAT32
#   T#246(sequential/MobilenetV3large/expanded_conv_14/squeeze_excite/Mul/mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#247(sequential/MobilenetV3large/expanded_conv_14/project/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/expanded_conv_14/project/Conv2D1) shape_signature:[-1, 7, 7, 160], type:FLOAT32
#   T#248(sequential/MobilenetV3large/expanded_conv_14/Add/add) shape_signature:[-1, 7, 7, 160], type:FLOAT32
#   T#249(sequential/MobilenetV3large/Conv_1/BatchNorm/FusedBatchNormV3;sequential/MobilenetV3large/Conv_1/Conv2D1) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#250(sequential/MobilenetV3large/multiply_39/mul;sequential/MobilenetV3large/tf.__operators__.add_28/y;sequential/MobilenetV3large/re_lu_77/Relu6;sequential/MobilenetV3large/tf.__operators__.add_55/AddV2;sequential/MobilenetV3large/tf.math.multiply_28/Mul/y;sequential/MobilenetV3large/tf.math.multiply_55/Mul) shape_signature:[-1, 7, 7, 960], type:FLOAT32
#   T#251(sequential/MobilenetV3large/avg_pool/Mean) shape_signature:[-1, 960], type:FLOAT32
#   T#252(sequential/dense/MatMul;sequential/dense/BiasAdd) shape_signature:[-1, 1], type:FLOAT32
#   T#253(StatefulPartitionedCall:0) shape_signature:[-1, 1], type:FLOAT32
#
# ---------------------------------------------------------------
# Your TFLite model has ‘1’ signature_def(s).
#
# Signature#0 key: 'serving_default'
# - Subgraph: Subgraph#0
# - Inputs:
#     'MobilenetV3large_input' : T#0
# - Outputs:
#     'dense' : T#253
#
# ---------------------------------------------------------------
#               Model size:   11910116 bytes
#     Non-data buffer size:      67172 bytes (00.56 %)
#   Total data buffer size:   11842944 bytes (99.44 %)
#     (Zero value buffers):          0 bytes (00.00 %)
#
# * Buffers of TFLite model are mostly used for constant tensors.
#   And zero value buffers are buffers filled with zeros.
#   Non-data buffers area are used to store operators, subgraphs and etc.
#   You can find more details from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/schema/schema.fbs

# %% [markdown]
# Start train

# %%
history_1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=300,
    steps_per_epoch=len(train_ds),
    validation_steps=len(val_ds)
)

print("\n==========================")
print("======= Train done =======")
print("==========================")
# Out:
# Epoch 1/300
uracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7041 - val_accuracy: 0.8850 - val_precision: 0.9096 - val_recall: 0.8550
# Epoch 299/300
# 51/51 [==============================] - 8s 138ms/step - loss: 2.9877e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7347 - val_accuracy: 0.8950 - val_precision: 0.9293 - val_recall: 0.8550
# Epoch 300/300
# 51/51 [==============================] - 8s 138ms/step - loss: 1.2903e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7197 - val_accuracy: 0.8925 - val_precision: 0.9243 - val_recall: 0.8550
#
# ==========================
# ======= Train done =======
# ==========================

# %% [markdown]
# Result #1 train

# %%
acc = history_1.history['accuracy']
prec = history_1.history['precision']
recall = history_1.history['recall']
loss = history_1.history['loss']

val_acc = history_1.history['val_accuracy']
val_prec = history_1.history['val_precision']
val_recall = history_1.history['val_recall']
val_loss = history_1.history['val_loss']

# %%
save_path = './Developed-model/exp11'
model.save(save_path)
print("\nModel has been saved")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) MobilenetV3large_input with unsupported characters which will be renamed to mobilenetv3large_input in the SavedModel.
# INFO:tensorflow:Assets written to: ./Developed-model/exp11\assets
# INFO:tensorflow:Assets written to: ./Developed-model/exp11\assets
# Model has been saved

# %%
print("\nEvaluating the model with test set")
model.evaluate(test_ds)
# Out:
# Evaluating the model with test set
# 13/13 [==============================] - 6s 143ms/step - loss: 0.4165 - accuracy: 0.9425 - precision: 0.9317 - recall: 0.9550
# [0.41647857427597046,
#  0.9424999952316284,
#  0.9317073225975037,
#  0.9549999833106995]

# %% [markdown]
# # Export Fine tune 1 metrics result to csv

# %%
data = [acc, prec, recall, loss, val_acc, val_prec, val_recall, val_loss]
export_data = zip_longest(*data, fillvalue = '')

with open('exp11.csv', 'w', encoding="ISO-8859-1", newline='') as file:
      write = csv.writer(file)
      write.writerow(("acc", "prec", "recall", "loss", "val_acc", "val_prec", "val_recall", "val_loss"))
      write.writerows(export_data)

print("\nTrain result has been saved")
# Out:
# Train result has been saved

# %%
plt.figure(figsize=(20, 16))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')

plt.subplot(2, 2, 3)
plt.plot(prec, label='Training Precision')
plt.plot(val_prec, label='Validation Precision')
plt.legend(loc='lower right')
plt.ylabel('Precision')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Precision')
plt.xlabel('epoch')

plt.subplot(2, 2, 4)
plt.plot(recall, label='Training Recall')
plt.plot(val_recall, label='Validation Recall')
plt.legend(loc='lower right')
plt.ylabel('Recall')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Recall')

plt.xlabel('epoch')
plt.show()
